# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

folder_path = 'datasets/'
df = pd.read_csv('datasets/athlete_events.csv')
regions = pd.read_csv(folder_path+'noc_regions.csv')
df = df.merge(regions, left_on='NOC', right_on='NOC')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
gdp = pd.read_csv(folder_path+'gdp.csv')
gdp.head()
gdp = gdp[['Entity','Year','GDP per capita']]
gdp.head()
# Out:
#         Entity  Year  GDP per capita
# 0  Afghanistan  1950          1156.0
# 1  Afghanistan  1951          1170.0
# 2  Afghanistan  1952          1189.0
# 3  Afghanistan  1953          1240.0
# 4  Afghanistan  1954          1245.0

# %%
health_exp = pd.read_csv(folder_path+'healthcare_expenditure_gdp.csv')
health_exp.drop(columns={'Code'}, inplace=True)
health_exp.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  2002
# 1  Afghanistan  2003
# 2  Afghanistan  2004
# 3  Afghanistan  2005
# 4  Afghanistan  2006
#
#    Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)
# 0                                               9.44
# 1                                               8.94
# 2                                               9.81
# 3                                               9.95
# 4                                              10.62

# %%
obesity = pd.read_csv(folder_path+'obesity_adults.csv')
obesity.drop(columns={'Code'}, inplace=True)
obesity.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1975
# 1  Afghanistan  1976
# 2  Afghanistan  1977
# 3  Afghanistan  1978
# 4  Afghanistan  1979
#
#    Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years
# 0                                                0.4
# 1                                                0.4
# 2                                                0.5
# 3                                                0.5
# 4                                                0.5

# %%
regime = pd.read_csv(folder_path+'political_regime.csv')
regime.drop(columns={'Code'}, inplace=True)
mapping = {0: 'closed autocracy', 1: 'electoral autocracy', 2: 'electoral democracy', 3: 'liberal democracy'}
regime['Political regime'] = regime['Political regime'].replace(mapping)
regime.head()
# Out:
#         Entity  Year  Political regime
# 0  Afghanistan  1789  closed autocracy
# 1  Afghanistan  1790  closed autocracy
# 2  Afghanistan  1791  closed autocracy
# 3  Afghanistan  1792  closed autocracy
# 4  Afghanistan  1793  closed autocracy

# %%
poverty = pd.read_csv(folder_path+'poverty.csv')
poverty = poverty[['Country', 'Year', 'Share below $10 a day']]
poverty.head()
# Out:
#    Country  Year  Share below $10 a day
# 0  Albania  1996              75.623880
# 1  Albania  2002              76.705050
# 2  Albania  2005              68.453090
# 3  Albania  2008              62.768870
# 4  Albania  2012              65.062386

# %%
population = pd.read_csv(folder_path+'population.csv')
population.drop(columns={'Code'}, inplace=True)
population.rename(columns={'Population (historical estimates)':'Population'}, inplace=True)
population['20_y_bef'] = population.groupby('Entity')['Population'].transform(lambda x: x.shift(3))

pop_500_y_bef = population.loc[(population['Year']>1590)&(population['Year']<1650)]
pop_500_y_bef = pop_500_y_bef.groupby('Entity')['Population'].max().reset_index()

pop_100_y_bef = population.loc[(population['Year']>1950)&(population['Year']<1960)]
pop_100_y_bef = pop_100_y_bef.groupby('Entity')['Population'].max().reset_index()

pop = population.sort_values(by='Year',ascending=False)
pop.drop_duplicates(subset='Entity', keep='first')
pop.reset_index(drop=True, inplace=True)

population = population.loc[population['Year']>1890]

# %%
df = df[(~df['Medal'].isna())&(df['Season']=='Summer')]
df = df.groupby(['Year','region'])['Medal'].count().reset_index().sort_values(by='Medal', ascending=False)

# %%
merged_df = gdp.merge(health_exp, how='outer', on=['Entity','Year'])
merged_df = merged_df.merge(obesity, how='outer', on=['Entity','Year'])
merged_df = merged_df.merge(regime, how='outer', on=['Entity','Year'])
merged_df = merged_df.merge(population, how='outer', on=['Entity','Year'])
merged_df = merged_df.merge(poverty, how='outer', left_on=['Entity','Year'], right_on=['Country','Year'])
merged_df = merged_df.merge(df, how='outer', left_on=['Entity','Year'], right_on=['region','Year'])

# %%
merged_df.head()
merged_df = merged_df.loc[merged_df['Year']>1890]
merged_df.drop(columns={'Country', 'region'}, inplace=True)
df_1_0 = merged_df.loc[(merged_df['Year']>1895)&(merged_df['Year']<2017)]
df_1_0.rename(columns={'GDP per capita':'GDP', 
                       'Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)':'Health exp', 
                       'Prevalence of obesity among adults, BMI >= 30 (crude estimate) (%) - Sex: both sexes - Age group: 18+  years':'Obesity',
                       '20_y_bef':'Population_20_y_bef',
                       'Share below $10 a day':'Poverty'}, inplace=True)

df_1_0.head()
# Out:
# /var/folders/bz/m_9l75x14kz_37vfj8r34b2r0000gn/T/ipykernel_13956/3594302385.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1_0.rename(columns={'GDP per capita':'GDP',
#           Entity  Year  GDP  Health exp  Obesity  Political regime  \
# 107  Afghanistan  1896  NaN         NaN      NaN  closed autocracy
# 108  Afghanistan  1897  NaN         NaN      NaN  closed autocracy
# 109  Afghanistan  1898  NaN         NaN      NaN  closed autocracy
# 110  Afghanistan  1899  NaN         NaN      NaN  closed autocracy
# 111  Afghanistan  1900  NaN         NaN      NaN  closed autocracy
#
#      Population  Population_20_y_bef  Poverty  Medal
# 107   4603230.0            4542568.0      NaN    NaN
# 108   4623613.0            4562708.0      NaN    NaN
# 109   4644079.0            4582928.0      NaN    NaN
# 110   4672084.0            4603230.0      NaN    NaN
# 111   4707744.0            4623613.0      NaN    NaN

# %%
print(df_1_0['Medal'].isna().size)
print(df_1_0.size)
df_1_0 = df_1_0.loc[~df_1_0['Medal'].isna()]
df_1_0.head()
# Out:
# 30409
# 304090
#           Entity  Year        GDP  Health exp  Obesity     Political regime  \
# 219  Afghanistan  2008  1319.6074       10.26      2.9  electoral autocracy
# 223  Afghanistan  2012  1945.0000        7.90      3.7  electoral autocracy
# 715      Algeria  1984  5361.0000         NaN      8.1     closed autocracy
# 723      Algeria  1992  4850.2230         NaN     11.2     closed autocracy
# 727      Algeria  1996  5451.6343         NaN     13.0                  NaN
#
#      Population  Population_20_y_bef  Poverty  Medal
# 219  26427204.0           24411196.0      NaN    1.0
# 223  30466484.0           27385310.0      NaN    1.0
# 715  21393532.0           19351356.0      NaN    2.0
# 723  26748302.0           24889516.0      NaN    2.0
# 727  28984640.0           27354326.0      NaN    3.0

# %%
df_1_0.columns
# Out:
# Index(['Entity', 'Year', 'GDP', 'Health exp', 'Obesity', 'Political regime',
#        'Population', 'Population_20_y_bef', 'Poverty', 'Medal'],
#       dtype='object')

# %%
sns.pairplot(df_1_0[['Entity','Poverty', 'Population', 'Population_20_y_bef', 'GDP', 'Health exp', 'Obesity', 'Political regime', 'Medal']])
plt.show()

# %%
correlation_matrix = df_1_0[['Poverty', 'Population', 'Population_20_y_bef', 'GDP', 'Health exp', 'Obesity', 'Medal']]
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
